# %% [markdown]
# <a href="https://colab.research.google.com/github/ramadhanifirdaus84/ramadhanif/blob/main/Algoritma%20percobaan%20Tes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Data mahasiswa
nama = ["Asep", "Budi", "Cecep"]

# Data nilai (MK1, MK2, MK3, MK4)
nilai = [
    [50, 70, 40, 80],  # Asep
    [78, 78, 80, 65],  # Budi
    [57, 88, 67, 69]   # Cecep
]

# =========================
# 1. Rata-rata tiap mahasiswa
# =========================
rata_mahasiswa = []

for i in range(len(nilai)):
    total = sum(nilai[i])
    rata = total / len(nilai[i])
    rata_mahasiswa.append(rata)

# cari yang tertinggi
maks = max(rata_mahasiswa)
index_mhs = rata_mahasiswa.index(maks)

# =========================
# 2. Rata-rata tiap mata kuliah
# =========================
rata_mk = []

for j in range(len(nilai[0])):  # jumlah kolom (MK)
    total = 0
    for i in range(len(nilai)):
        total += nilai[i][j]
    rata = total / len(nilai)
    rata_mk.append(rata)

# cari yang terkecil
min_mk = min(rata_mk)
index_mk = rata_mk.index(min_mk)

# =========================
# OUTPUT
# =========================
print("Mahasiswa Terpintar :", nama[index_mhs], "(Nilai :", round(maks, 2), ")")
print("Mata Kuliah Nilai Terkecil : MK", index_mk + 1, "(Nilai :", round(min_mk, 2), ")")
